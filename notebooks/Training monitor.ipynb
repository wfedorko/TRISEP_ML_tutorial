# %% [markdown]
# # This notebook is meant as a tool to monitor the training process

# %%
import os,sys
currentdir = os.getcwd()
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir)

# %%
from utils import plot_utils

# %%
# %matplotlib inline

# %% [markdown]
# You will need to change the location of where these files are

# %%
loc="../model_state_dumps/20190727_003326"

# %%
plot_utils.disp_learn_hist(loc,losslim=3.0)

# %%
plot_utils.disp_learn_hist_smoothed(loc,window_val=1)
